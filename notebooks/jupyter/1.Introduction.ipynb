# %% [markdown]
# # IPython 3 (jupyter)
#
# ##Upgrade to the new version
#
# ```
# sudo pip install --upgrade ipyton
# sudo pip install --upgrade "ipython[notebook]"
# ```
#
# ##Enabling Python3
#
# http://jupyter.cs.brynmawr.edu/hub/dblank/public/Jupyter%20Help.ipynb#1.4.2-Enable-Python-3-kernel
#
# You have to run these two blocks of code in ipython.

# %%
! mkdir -p ~/.ipython/kernels/python3

# %%
# %%file ~/.ipython/kernels/python3/kernel.json
#
# {
#  "display_name": "Python 3",
#  "language": "python",
#  "argv": [
#   "python3",
#   "-c", "from IPython.kernel.zmq.kernelapp import main; main()",
#   "-f", "{connection_file}"
#  ],
#  "codemirror_mode": {
#   "version": 2,
#   "name": "ipython"
#  }
# }

# %% [markdown]
# ##Why is it called jupyter?
#
# <img src="http://jupyter.org/images/jupyter-sq-text.svg" style="width:50%;height:50%">
#
# The name represents the new direction od IPython development. They moving away from linking the IPython platform with a single language. The way it works is as follows:

# %%
from IPython.display import Image
Image(filename='kernel.png')

# %% [markdown]
# $$Julia + Python + R = jupyter$$
#
# ###But there is another reason
#
# Jupiter has been thought of in Roman mythology is a God who is rival to Zeus from Greek mythology. The mystery around Jupiter and other planets and stars lead people to think of them as Gods; where even Kings used to assign astrolegers as advisers.
#
# ![](http://upload.wikimedia.org/wikipedia/commons/c/cb/Jupiter-bonatti.png)
#
# Galileo documented his observasions about Jupiter's moons and published them in the Sidereus Nuncius (Starry Messenger) back in 1610 which was a pamphlet they he published. This was the first paper ever published about astronomy that used observations using a telescope. He has proven that the Earth orbits the Sun like Jupiter's moons orbit Jupiter.
#
# > "I therefore concluded and decided unhesitatingly, that there are three stars in the heavens moving about Jupiter, as Venus and Mercury round the Sun; which at length was established as clear as daylight by numerous subsequent observations. These observations also established that there are not only three, but four, erratic sidereal bodies performing their revolutions round Jupiter...the revolutions are so swift that an observer may generally get differences of position every hour."
# >
# > Galileo trans Carlos, 1880, p47.
#
# <img src="http://upload.wikimedia.org/wikipedia/commons/d/d0/Sidereus_Nuncius_Medicean_Stars.jpg">
# <center>Image(s) courtesy of the History of Science Collections, University of Oklahoma Libraries.</center>
#
# Sharing these observations and conclusions in a way that can be replicated and verified inspired the modern scientific method. This is what IPython Notebooks is used for; sharing the complete process with others to verify your process and replicate your results.
#
#
# #So what's new?
#
# http://ipython.org/ipython-doc/3/whatsnew/version3.html
#
# > 3.x will be the last monolithic release of IPython, as the next release cycle will see the growing project split into its Python-specific and language-agnostic components.
# >
# > **http://ipython.org/ipython-doc/3/whatsnew/version3.html**
#
# ##1. Notebooks with different kernels
# https://github.com/ipython/ipython/wiki/IPython-kernels-for-other-languages
#
# ![](http://ipython.org/ipython-doc/3/_images/kernel_selector_screenshot.png)
# ##2. Unicode Identifiers
# **Works ONLY with Python3**
#
# Type \alpha Then Press Tab.

# %%
α = 1
β = 2
α / β
# Out:
# 0.5

# %% [markdown]
# ##3. Widgets are **NOT** Backwards Compatible
#
# http://ipython.org/ipython-doc/3/whatsnew/version3_widget_migration.html
#
# ##4. No Header Cells
# You can now use heading inside inside a markdown cell and you will get a bookmark link.
#
# ##5. Text Editor
# A multilingual text editor is added with highlighting for many programming and scripting languages.
#
# ##6. Static File Server
# You can serve static files using http://url:port/files/%FILE_PATH% like http://0.0.0.0:8888/files/myproject/README.html
#
# ##7. Build-it Terminal
# You can start a termenal from jupyter to access your machine. Thanks foto the development team for making it black background with white text.
#
# ##8. Google Drive support for Jupyter Notebook
# You can share jupyter notebooks from your Google Drive using the new colaboratory features. This allows you share jupyter notebooks like NBViewr. The major new features is you can connect colaboratory to an IPython kernel to allow execution of code within colaboratory.
